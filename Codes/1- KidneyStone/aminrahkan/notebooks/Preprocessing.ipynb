# %%
import os 
import sys 
from pathlib import Path
sys.path.append(os.path.abspath(".."))
from config.config import DATASET_PATH,PROJECT_ADDRESS
from src.data.preprocessing import prepare_dataset_folders, show_sample_images

DATASET_PATH = Path(DATASET_PATH)
print("DataSet Path 1 : ",DATASET_PATH)
DATASET_PATH=str(DATASET_PATH)
DATASET_PATH = DATASET_PATH.replace('\\', '')
print("DataSet Path 2 : ",DATASET_PATH)
prepare_dataset_folders(DATASET_PATH,output_base=PROJECT_ADDRESS/"dataset",train_ratio=0.7,val_ratio=0.15,test_ratio=0.15)


show_sample_images(Path(DATASET_PATH),"stone",4)
show_sample_images(Path(DATASET_PATH),"Normal",4)
# Out:
# DataSet Path 1 :  /Users/nic/Documents/Work/Ai Project's/MIT/Datasets/1- KideyStone/archive
# DataSet Path 2 :  /Users/nic/Documents/Work/Ai Project's/MIT/Datasets/1- KideyStone/archive
# Normal - 4414 files
# train_end: 3089 - val_end : 662
# train:3089 files
# validate:662 files
# test:3752 files
# Stone - 5002 files
# train_end: 3501 - val_end : 750
# train:3501 files
# validate:750 files
# test:4252 files
# folder_path : /Users/nic/Documents/Work/Ai Project's/MIT/Datasets/1- KideyStone/archive/stone in show_sample_images
# folder_path : /Users/nic/Documents/Work/Ai Project's/MIT/Datasets/1- KideyStone/archive/Normal in show_sample_images
